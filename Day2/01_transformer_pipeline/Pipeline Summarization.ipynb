# %% [markdown]
# <a href="https://colab.research.google.com/github/Tuchsanai/AIMaster-seagate-training-2024/blob/main/Day2/transformer_pipeline/Pipeline%20Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -nc https://raw.githubusercontent.com/Tuchsanai/AIMaster-seagate-training-2024/main/Dataset/bbc_text_cls.csv
# Out:
# --2024-05-21 02:58:43--  https://raw.githubusercontent.com/Tuchsanai/AIMaster-seagate-training-2024/main/Dataset/bbc_text_cls.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5085081 (4.8M) [text/plain]
# Saving to: ‘bbc_text_cls.csv’
#
# bbc_text_cls.csv    100%[===================>]   4.85M  --.-KB/s    in 0.07s
#
# 2024-05-21 02:58:43 (73.4 MB/s) - ‘bbc_text_cls.csv’ saved [5085081/5085081]

# %%
#!pip install transformers

# %%
import os
os.environ['HF_TOKEN'] = "your_hugging_face_token_here"

# %%
import pandas as pd
import numpy as np
import textwrap
from transformers import pipeline

# %%
df = pd.read_csv('bbc_text_cls.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2225 non-null   object
#  1   labels  2225 non-null   object
# dtypes: object(2)
# memory usage: 34.9+ KB

# %%
df.head(10)
# Out:
#                                                 text    labels
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business
# 3  High fuel prices hit BA's profits\n\nBritish A...  business
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business
# 5  Japan narrowly escapes recession\n\nJapan's ec...  business
# 6  Jobs growth still slow in the US\n\nThe US cre...  business
# 7  India calls for fair trade rules\n\nIndia, whi...  business
# 8  Ethiopia's crop production up 24%\n\nEthiopia ...  business
# 9  Court rejects $280bn tobacco case\n\nA US gove...  business

# %%
df['labels'].value_counts()
# Out:
# labels
# sport            511
# business         510
# politics         417
# tech             401
# entertainment    386
# Name: count, dtype: int64

# %%
doc = df[df.labels == 'business']['text'].sample(random_state=42)

# %%
print(doc.iloc[0])
# Out:
# Christmas sales worst since 1981
#
# UK retail sales fell in December, failing to meet expectations and making it by some counts the worst Christmas since 1981.
#
# Retail sales dropped by 1% on the month in December, after a 0.6% rise in November, the Office for National Statistics (ONS) said. The ONS revised the annual 2004 rate of growth down from the 5.9% estimated in November to 3.2%. A number of retailers have already reported poor figures for December. Clothing retailers and non-specialist stores were the worst hit with only internet retailers showing any significant growth, according to the ONS.
#
# The last time retailers endured a tougher Christmas was 23 years previously, when sales plunged 1.7%.
#
# ...

# %%
def wrap(x):
  return textwrap.fill(x, replace_whitespace=False, fix_sentence_endings=True)

print(wrap(doc.iloc[0]))
# Out:
# Christmas sales worst since 1981
#
# UK retail sales fell in December,
# failing to meet expectations and making it by some counts the worst
# Christmas since 1981.
#
# Retail sales dropped by 1% on the month in
# December, after a 0.6% rise in November, the Office for National
# Statistics (ONS) said.  The ONS revised the annual 2004 rate of growth
# down from the 5.9% estimated in November to 3.2%. A number of
# retailers have already reported poor figures for December.  Clothing
# retailers and non-specialist stores were the worst hit with only
# internet retailers showing any significant growth, according to the
# ONS.
#
# The last time retailers endured a tougher Christmas was 23 years
# previously, when sales plunged 1.7%.
#
# The ONS echoed an earlier
# caution from Bank of England governor Mervyn King not to read too much
# into the poor December figures.  Some analysts put a positive gloss on
# the figures, pointing out that the non-seasonally-adjusted figures
# ...

# %%
summarizer = pipeline("summarization",model="sshleifer/distilbart-cnn-12-6")

summarizer

# %%
Text = wrap(doc.iloc[0])
results = summarizer(Text)

# %%
wrap(results[0]['summary_text'])
# Out:
# ' Retail sales dropped by 1% on the month in December, after a 0.6%\nrise in November . Clothing and internet retailers were the worst hit\nwith only internet retailers showing significant growth . The last\ntime retailers endured a tougher Christmas was 23 years ago, when\nsales plunged 1.7% .'

# %% [markdown]
# # Apply for thai
#
# https://huggingface.co/preechanon/mt5-base-thaisum-text-summarization

# %%
from transformers import pipeline

# Initialize the summarization pipeline using the mT5 model
summarizer = pipeline("summarization", model="preechanon/mt5-base-thaisum-text-summarization")

# Example text in Thai
thai_text = """
กรุงเทพมหานคร หรือชื่อที่รู้จักกันทั่วไปว่า "กรุงเทพฯ" เป็นเมืองหลวงและเป็นศูนย์กลางทางเศรษฐกิจ การเมือง และวัฒนธรรมของประเทศไทย ด้วยประชากรกว่า 8 ล้านคน กรุงเทพฯ จึงเป็นเมืองที่มีประชากรหนาแน่นที่สุดในประเทศ และยังเป็นหนึ่งในเมืองที่ใหญ่ที่สุดในภูมิภาคเอเชียตะวันออกเฉียงใต้อีกด้วย

กรุงเทพฯ ตั้งอยู่บนที่ราบลุ่มแม่น้ำเจ้าพระยาในภาคกลางของประเทศไทย มีอาณาเขตครอบคลุมพื้นที่กว่า 1,500 ตารางกิโลเมตร เมืองนี้มีประวัติศาสตร์อันยาวนานกว่า 200 ปี นับตั้งแต่การสถาปนาราชวงศ์จักรีและย้ายเมืองหลวงจากกรุงธนบุรีมายังกรุงเทพฯ ในปี พ.ศ. 2325

กรุงเทพฯ เป็นเมืองที่มีความหลากหลายและมีเสน่ห์เฉพาะตัว เป็นที่ผสมผสานของวัฒนธรรมไทยดั้งเดิมและความทันสมัยแบบตะวันตก มีทั้งวัดวาอารามที่สวยงาม อาคารสถาปัตยกรรมร่วมสมัย ศูนย์การค้าขนาดใหญ่ และสวนสาธารณะอันร่มรื่น นอกจากนี้ กรุงเทพฯ ยังเป็นที่ตั้งของสถานที่ท่องเที่ยวที่มีชื่อเสียงระดับโลก เช่น วัดพระแก้ว พระบรมมหาราชวัง และตลาดนัดจตุจักร

ในด้านเศรษฐกิจ กรุงเทพฯ เป็นศูนย์กลางทางการเงินและธุรกิจที่สำคัญของประเทศไทย มีบริษัทชั้นนำทั้งในและต่างประเทศมาตั้งสำนักงานในเมืองนี้เป็นจำนวนมาก รวมถึงเป็นที่ตั้งของตลาดหลักทรัพย์แห่งประเทศไทย ซึ่งเป็นตลาดหลักทรัพย์ที่ใหญ่ที่สุดในภูมิภาคเอเชียตะวันออกเฉียงใต้

ด้วยความหลากหลายทางวัฒนธรรม แหล่งท่องเที่ยวที่น่าสนใจ และความเจริญทางเศรษฐกิจ ทำให้กรุงเทพฯ เป็นจุดหมายปลายทางยอดนิยมของนักท่องเที่ยวจากทั่วโลก และเป็นเมืองที่มีเสน่ห์ดึงดูดผู้คนให้เข้ามาสัมผัสถึงมนต์เสน่ห์อันน่าหลงใหลของเมืองหลวงแห่งนี้
"""
# Out:
# config.json:   0%|          | 0.00/941 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/226 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/833 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/416 [00:00<?, ?B/s]

# %%
# Perform summarization on the Thai text
summary = summarizer(thai_text, max_length=50, min_length=30)

# Print the summarized text
print(summary[0]['summary_text'])
# Out:
# กรุงเทพฯ คือ หัวใจของประเทศไทย ทั้งในด้านการเมือง การเศรษฐกิจ และวัฒนธรรม เป็นเมืองที่มีการผสมผสานระหว่างวัฒนธรรมโบราณกับสมัยใหม่ได้อย่างลงตัว มีสถานที่ท่องเที่ยวมากมาย ทั้งพระบรมมหาราชวัง วัดพระแก้ว และถนนข้าวสาร

# %% [markdown]
# # Full model

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

tokenizer = AutoTokenizer.from_pretrained("preechanon/mt5-base-thaisum-text-summarization")
model = AutoModelForSeq2SeqLM.from_pretrained("preechanon/mt5-base-thaisum-text-summarization")

# %%
model
# Out:
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 768)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
# ...

# %%
thai_text = """
กรุงเทพมหานคร หรือชื่อที่รู้จักกันทั่วไปว่า "กรุงเทพฯ" เป็นเมืองหลวงและเป็นศูนย์กลางทางเศรษฐกิจ การเมือง และวัฒนธรรมของประเทศไทย ด้วยประชากรกว่า 8 ล้านคน กรุงเทพฯ จึงเป็นเมืองที่มีประชากรหนาแน่นที่สุดในประเทศ และยังเป็นหนึ่งในเมืองที่ใหญ่ที่สุดในภูมิภาคเอเชียตะวันออกเฉียงใต้อีกด้วย

กรุงเทพฯ ตั้งอยู่บนที่ราบลุ่มแม่น้ำเจ้าพระยาในภาคกลางของประเทศไทย มีอาณาเขตครอบคลุมพื้นที่กว่า 1,500 ตารางกิโลเมตร เมืองนี้มีประวัติศาสตร์อันยาวนานกว่า 200 ปี นับตั้งแต่การสถาปนาราชวงศ์จักรีและย้ายเมืองหลวงจากกรุงธนบุรีมายังกรุงเทพฯ ในปี พ.ศ. 2325

กรุงเทพฯ เป็นเมืองที่มีความหลากหลายและมีเสน่ห์เฉพาะตัว เป็นที่ผสมผสานของวัฒนธรรมไทยดั้งเดิมและความทันสมัยแบบตะวันตก มีทั้งวัดวาอารามที่สวยงาม อาคารสถาปัตยกรรมร่วมสมัย ศูนย์การค้าขนาดใหญ่ และสวนสาธารณะอันร่มรื่น นอกจากนี้ กรุงเทพฯ ยังเป็นที่ตั้งของสถานที่ท่องเที่ยวที่มีชื่อเสียงระดับโลก เช่น วัดพระแก้ว พระบรมมหาราชวัง และตลาดนัดจตุจักร

ในด้านเศรษฐกิจ กรุงเทพฯ เป็นศูนย์กลางทางการเงินและธุรกิจที่สำคัญของประเทศไทย มีบริษัทชั้นนำทั้งในและต่างประเทศมาตั้งสำนักงานในเมืองนี้เป็นจำนวนมาก รวมถึงเป็นที่ตั้งของตลาดหลักทรัพย์แห่งประเทศไทย ซึ่งเป็นตลาดหลักทรัพย์ที่ใหญ่ที่สุดในภูมิภาคเอเชียตะวันออกเฉียงใต้

ด้วยความหลากหลายทางวัฒนธรรม แหล่งท่องเที่ยวที่น่าสนใจ และความเจริญทางเศรษฐกิจ ทำให้กรุงเทพฯ เป็นจุดหมายปลายทางยอดนิยมของนักท่องเที่ยวจากทั่วโลก และเป็นเมืองที่มีเสน่ห์ดึงดูดผู้คนให้เข้ามาสัมผัสถึงมนต์เสน่ห์อันน่าหลงใหลของเมืองหลวงแห่งนี้
"""

input_ = tokenizer(thai_text, truncation=True, max_length=1024, return_tensors="pt")


input_
# Out:
# {'input_ids': tensor([[   259, 111284,  11440,  38389,   1549, 118547,   7428,  77093,   6582,
#             313, 154440,    311,  21191,  24633, 108364, 142987, 224344,   9542,
#          115204,    259, 192537,   3324, 133931,   1881,  94117,  66418, 167509,
#           58384,  23000,    630, 111034,  11821,    259, 154440,    259, 200755,
#           24633,  18095, 167509,  58384, 149625, 174961,  30488, 161499,   3324,
#           21746, 197578,  24633,   1549,  25889, 223417, 186270, 103740, 203625,
#          155017, 163388,  89051,  98871,    259, 154440,    259, 194178,  17383,
#            1549, 208727,   7910, 139858, 191413,  33559,  20921,  22401,   2361,
#           30931,  45984,   1881,  94117,  13596,  44628, 208385,  68069, 215034,
#           42576,  23000,    259,  92821,  55964, 156514,  77387,    259,  24633,
#          178686, 156278,  40077, 196544,  23000,   1950,  24250,    259,  99216,
# ...

# %%
with torch.no_grad():
    preds = model.generate(
        input_['input_ids'].to('cpu'),
        num_beams=15,
        num_return_sequences=1,
        no_repeat_ngram_size=1,
        remove_invalid_values=True,
        max_length=140,
    )

summary = tokenizer.decode(preds[0], skip_special_tokens=True)
summary
# Out:
# 'กรุงเทพฯ เป็นเมืองที่มีความหลากหลายและมีเสน่ห์เฉพาะตัว มีอาคารสถาปัตยกรรมร่วมสมัย ศูนย์การค้าขนาดใหญ่ และสวนสาธารณะอันร่มรื่น นอกจากนี้ยังตั้งอยู่บนที่ราบลุ่มแม่น้ําเจ้าพระยาในภาคกลางของประเทศไทย'
