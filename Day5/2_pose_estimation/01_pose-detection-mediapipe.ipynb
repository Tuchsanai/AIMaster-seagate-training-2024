# %% [markdown]
# # Importing Necessary Libraries

# %%
# !pip install mediapipe

from IPython.display import clear_output
clear_output()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
from time import time
import mediapipe as mp
import cv2 as cv

# %% [markdown]
# # Init Project

# %%
mpPose = mp.solutions.pose
mpDraw = mp.solutions.drawing_utils

# %%
pose = mpPose.Pose(
    static_image_mode=True,
    min_detection_confidence=0.3,
    model_complexity=2
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717627555.115302       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M1 Max

# %%
 landmark_keys = [landmark.name for landmark in mp_pose.PoseLandmark]
 landmark_keys
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 landmark_keys = [landmark.name for landmark in mp_pose.PoseLandmark]
#       2 landmark_keys
#
# NameError: name 'mp_pose' is not defined

# %% [markdown]
# # Read & Perform

# %%
image = cv.imread('./Karate00.jpg')
plt.figure(figsize=[12, 12])
plt.title('Sample')
plt.axis('off')
plt.imshow(image[:, :, ::-1])
plt.show()

# %%
result = pose.process(cv.cvtColor(image, cv.COLOR_BGR2RGB))

for key, landmark in zip(landmark_keys, result.pose_landmarks.landmark):
    print(key,"x : ", landmark.x, "y:", landmark.y, "z:", landmark.z)
# Out:
# NOSE x :  0.6431248188018799 y: 0.20099282264709473 z: -0.20505136251449585
# LEFT_EYE_INNER x :  0.6504138112068176 y: 0.18378186225891113 z: -0.21381860971450806
# LEFT_EYE x :  0.6549507975578308 y: 0.18285423517227173 z: -0.21405187249183655
# LEFT_EYE_OUTER x :  0.6598300337791443 y: 0.181339293718338 z: -0.21397104859352112
# RIGHT_EYE_INNER x :  0.6463058590888977 y: 0.18372491002082825 z: -0.18967995047569275
# RIGHT_EYE x :  0.6471721529960632 y: 0.18338316679000854 z: -0.19008588790893555
# RIGHT_EYE_OUTER x :  0.6481807231903076 y: 0.18286988139152527 z: -0.19023047387599945
# LEFT_EAR x :  0.6850773692131042 y: 0.1823788285255432 z: -0.1859705001115799
# RIGHT_EAR x :  0.6711350083351135 y: 0.18570160865783691 z: -0.06888792663812637
# MOUTH_LEFT x :  0.6522658467292786 y: 0.21892935037612915 z: -0.18709178268909454
# MOUTH_RIGHT x :  0.6474590301513672 y: 0.21890294551849365 z: -0.15509766340255737
# LEFT_SHOULDER x :  0.7619495987892151 y: 0.30855321884155273 z: -0.13642223179340363
# RIGHT_SHOULDER x :  0.631685197353363 y: 0.2680380344390869 z: -0.007268930319696665
# LEFT_ELBOW x :  0.763130247592926 y: 0.43288955092430115 z: -0.27360713481903076
# RIGHT_ELBOW x :  0.5340350866317749 y: 0.2683902978897095 z: -0.057300351560115814
# LEFT_WRIST x :  0.7370771169662476 y: 0.4833623170852661 z: -0.5147759914398193
# RIGHT_WRIST x :  0.443189799785614 y: 0.20307451486587524 z: -0.2541080713272095
# LEFT_PINKY x :  0.7274063229560852 y: 0.4911859929561615 z: -0.5664441585540771
# RIGHT_PINKY x :  0.4131186604499817 y: 0.19890207052230835 z: -0.2909451425075531
# LEFT_INDEX x :  0.7223489284515381 y: 0.4761202037334442 z: -0.5867187976837158
# RIGHT_INDEX x :  0.4118642807006836 y: 0.19760718941688538 z: -0.3195059597492218
# LEFT_THUMB x :  0.7214078307151794 y: 0.4731498658657074 z: -0.5269042253494263
# RIGHT_THUMB x :  0.42285996675491333 y: 0.20245492458343506 z: -0.2727462351322174
# LEFT_HIP x :  0.6295342445373535 y: 0.5579255819320679 z: -0.015249980613589287
# RIGHT_HIP x :  0.5736181139945984 y: 0.485945463180542 z: 0.014864490367472172
# LEFT_KNEE x :  0.6517248153686523 y: 0.7475401163101196 z: -0.30907443165779114
# RIGHT_KNEE x :  0.42144179344177246 y: 0.47442734241485596 z: -0.1486886739730835
# LEFT_ANKLE x :  0.5257462859153748 y: 0.6187878847122192 z: 0.006115916185081005
# RIGHT_ANKLE x :  0.26277637481689453 y: 0.45296573638916016 z: -0.1186736673116684
# LEFT_HEEL x :  0.5276756882667542 y: 0.5768398642539978 z: 0.0391182005405426
# RIGHT_HEEL x :  0.2422884702682495 y: 0.45718246698379517 z: -0.11495155096054077
# LEFT_FOOT_INDEX x :  0.45364272594451904 y: 0.5847046971321106 z: -0.020437760278582573
# RIGHT_FOOT_INDEX x :  0.22492605447769165 y: 0.43933311104774475 z: -0.21078719198703766

# %%
imagecopy = image.copy()

if result.pose_landmarks:
    mpDraw.draw_landmarks(
        image=imagecopy ,
        landmark_list=result.pose_landmarks,
        connections=mpPose.POSE_CONNECTIONS
    )
    fig = plt.figure(figsize=[10, 10])
    plt.title('Export')
    plt.axis('off')
    plt.imshow(imagecopy[:, :, ::-1])
    plt.show()

# %%
mpDraw.plot_landmarks(
    result.pose_world_landmarks,
    mpPose.POSE_CONNECTIONS
)

# %% [markdown]
# # How to Plot Multi images

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Initialize MediaPipe Pose module
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

# List of image paths
image_paths = ['Karate00.jpg', 'Karate01.jpg']  # Replace with your image paths

# Function to draw landmarks on an image
def draw_landmarks(image, landmarks):
    mp_drawing.draw_landmarks(image, landmarks, mp_pose.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                              mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

# Custom function to plot 3D landmarks
def plot_3d_landmarks(landmarks, ax):
    for landmark in landmarks.landmark:
        ax.scatter(landmark.x, landmark.y, landmark.z, color='blue')

    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Z axis')

# Iterate over each image path
for image_path in image_paths:
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)

    if results.pose_landmarks:
        draw_landmarks(image, results.pose_landmarks)

        # Create a figure for subplots
        fig = plt.figure(figsize=(15, 5))

        # Create a subplot for the image
        ax_image = fig.add_subplot(1, 2, 1)
        ax_image.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        ax_image.title.set_text(f"Pose Landmarks: {image_path}")
        ax_image.axis('off')

        # Create a 3D subplot for the landmarks
        ax_3d = fig.add_subplot(1, 2, 2, projection='3d')
        plot_3d_landmarks(results.pose_landmarks, ax_3d)
        ax_3d.title.set_text("3D Pose Landmarks")

        plt.show()
    else:
        print(f"No pose landmarks detected in {image_path}.")

# Release resources
pose.close()
# Out:
# I0000 00:00:1702464714.361848       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1 Max

# %% [markdown]
# # Create Dataset

# %%
import cv2
import mediapipe as mp
import pandas as pd

# Initialize MediaPipe Pose module
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

# Load an image
image_path = 'Karate00.jpg'  # Replace with your image path
image = cv2.imread(image_path)

# Process the image and perform pose estimation
results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# Check if landmarks were detected
if results.pose_landmarks:
    # Get the list of landmark keys
    landmark_keys = [landmark.name for landmark in mp_pose.PoseLandmark]

    # Prepare data for DataFrame
    pose_data = {}
    for key, landmark in zip(landmark_keys, results.pose_landmarks.landmark):
        pose_data[f'{key}_x'] = landmark.x
        pose_data[f'{key}_y'] = landmark.y
        pose_data[f'{key}_z'] = landmark.z
        pose_data[f'{key}_visibility'] = landmark.visibility

    # Create a DataFrame
    df = pd.DataFrame([pose_data])
  
   
else:
    print("No pose landmarks detected.")

# Release resources
pose.close()
# Out:
# I0000 00:00:1702462030.646453       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1 Max

# %%
df
# Out:
#      NOSE_x    NOSE_y   NOSE_z  NOSE_visibility  LEFT_EYE_INNER_x  \
# 0  0.642803  0.198573 -0.11632         0.994962          0.652303
#
#    LEFT_EYE_INNER_y  LEFT_EYE_INNER_z  LEFT_EYE_INNER_visibility  LEFT_EYE_x  \
# 0          0.181638         -0.130272                   0.994621     0.65627
#
#    LEFT_EYE_y  ...  RIGHT_HEEL_z  RIGHT_HEEL_visibility  LEFT_FOOT_INDEX_x  \
# 0    0.181375  ...      0.108525                 0.9571           0.476805
#
#    LEFT_FOOT_INDEX_y  LEFT_FOOT_INDEX_z  LEFT_FOOT_INDEX_visibility  \
# 0           0.612715            0.17105                    0.674121
#
#    RIGHT_FOOT_INDEX_x  RIGHT_FOOT_INDEX_y  RIGHT_FOOT_INDEX_z  \
# 0             0.22706            0.434448            0.038911
#
#    RIGHT_FOOT_INDEX_visibility
# 0                     0.952575
#
# [1 rows x 132 columns]

# %% [markdown]
# # Create Train Dataset for Multi images

# %%
import cv2
import mediapipe as mp
import pandas as pd

# Initialize MediaPipe Pose module
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

# List of image paths
image_paths = ['Karate00.jpg', 'Karate01.jpg']  # Replace with your image paths

# Initialize a list to store pose data for each image
all_pose_data = []

# Iterate over each image path
for image_path in image_paths:
    image = cv2.imread(image_path)
    results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

    if results.pose_landmarks:
        # Get the list of landmark keys
        landmark_keys = [landmark.name for landmark in mp_pose.PoseLandmark]

        # Prepare data for DataFrame
        pose_data = {'image_path': image_path}
        for key, landmark in zip(landmark_keys, results.pose_landmarks.landmark):
            pose_data[f'{key}_x'] = landmark.x
            pose_data[f'{key}_y'] = landmark.y
            pose_data[f'{key}_z'] = landmark.z
            pose_data[f'{key}_visibility'] = landmark.visibility

        # Append pose data to the list
        all_pose_data.append(pose_data)
    else:
        print(f"No pose landmarks detected in {image_path}.")

# Release resources
pose.close()

# Convert the list of pose data into a DataFrame
pose_df = pd.DataFrame(all_pose_data)
# Out:
# I0000 00:00:1702462389.545681       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1 Max

# %%
pose_df
# Out:
#      image_path    NOSE_x    NOSE_y    NOSE_z  NOSE_visibility  \
# 0  Karate00.jpg  0.642803  0.198573 -0.116320         0.994962
# 1  Karate01.jpg  0.776372  0.346803 -0.257662         0.998321
#
#    LEFT_EYE_INNER_x  LEFT_EYE_INNER_y  LEFT_EYE_INNER_z  \
# 0          0.652303          0.181638         -0.130272
# 1          0.792239          0.339093         -0.265740
#
#    LEFT_EYE_INNER_visibility  LEFT_EYE_x  ...  RIGHT_HEEL_z  \
# 0                   0.994621    0.656270  ...      0.108525
# 1                   0.999519    0.796645  ...     -0.080330
#
#    RIGHT_HEEL_visibility  LEFT_FOOT_INDEX_x  LEFT_FOOT_INDEX_y  \
# 0               0.957100           0.476805           0.612715
# 1               0.978516           0.548620           0.366093
#
#    LEFT_FOOT_INDEX_z  LEFT_FOOT_INDEX_visibility  RIGHT_FOOT_INDEX_x  \
# 0           0.171050                    0.674121            0.227060
# 1          -0.007628                    0.725184            0.569533
#
#    RIGHT_FOOT_INDEX_y  RIGHT_FOOT_INDEX_z  RIGHT_FOOT_INDEX_visibility
# 0            0.434448            0.038911                     0.952575
# 1            0.867478           -0.158631                     0.968210
#
# [2 rows x 133 columns]

# %% [markdown]
# # Yolo v8 pose estimation
#
# https://alimustoofaa.medium.com/yolov8-pose-estimation-and-pose-keypoint-classification-using-neural-net-pytorch-98469b924525
#
#
# https://alimustoofaa.medium.com/yolov8-pose-estimation-and-pose-keypoint-classification-using-neural-net-pytorch-98469b924525
